# %%
#imports

import string

# %%
list_of_acceptable_wells =[]
for row in list(string.ascii_uppercase[2:14]):
    for column in range(2,22):
        list_of_acceptable_wells.append(str(row) + str(column))

# %%
my_list = []

for i in list_of_acceptable_wells:
    tmp_dict = {}
    tmp_dict['name'] = i
    tmp_dict['color'] = -12566464
    my_list.append(tmp_dict)

# %%
my_list
# Out:
# [{'name': 'C2', 'color': -12566464},
#  {'name': 'C3', 'color': -12566464},
#  {'name': 'C4', 'color': -12566464},
#  {'name': 'C5', 'color': -12566464},
#  {'name': 'C6', 'color': -12566464},
#  {'name': 'C7', 'color': -12566464},
#  {'name': 'C8', 'color': -12566464},
#  {'name': 'C9', 'color': -12566464},
#  {'name': 'C10', 'color': -12566464},
#  {'name': 'C11', 'color': -12566464},
#  {'name': 'C12', 'color': -12566464},
#  {'name': 'C13', 'color': -12566464},
#  {'name': 'C14', 'color': -12566464},
#  {'name': 'C15', 'color': -12566464},
#  {'name': 'C16', 'color': -12566464},
#  {'name': 'C17', 'color': -12566464},
#  {'name': 'C18', 'color': -12566464},
#  {'name': 'C19', 'color': -12566464},
#  {'name': 'C20', 'color': -12566464},
#  {'name': 'C21', 'color': -12566464},
#  {'name': 'D2', 'color': -12566464},
#  {'name': 'D3', 'color': -12566464},
#  {'name': 'D4', 'color': -12566464},
#  {'name': 'D5', 'color': -12566464},
#  {'name': 'D6', 'color': -12566464},
#  {'name': 'D7', 'color': -12566464},
#  {'name': 'D8', 'color': -12566464},
#  {'name': 'D9', 'color': -12566464},
#  {'name': 'D10', 'color': -12566464},
#  {'name': 'D11', 'color': -12566464},
#  {'name': 'D12', 'color': -12566464},
#  {'name': 'D13', 'color': -12566464},
#  {'name': 'D14', 'color': -12566464},
#  {'name': 'D15', 'color': -12566464},
#  {'name': 'D16', 'color': -12566464},
#  {'name': 'D17', 'color': -12566464},
#  {'name': 'D18', 'color': -12566464},
#  {'name': 'D19', 'color': -12566464},
#  {'name': 'D20', 'color': -12566464},
#  {'name': 'D21', 'color': -12566464},
#  {'name': 'E2', 'color': -12566464},
#  {'name': 'E3', 'color': -12566464},
#  {'name': 'E4', 'color': -12566464},
#  {'name': 'E5', 'color': -12566464},
#  {'name': 'E6', 'color': -12566464},
#  {'name': 'E7', 'color': -12566464},
#  {'name': 'E8', 'color': -12566464},
#  {'name': 'E9', 'color': -12566464},
#  {'name': 'E10', 'color': -12566464},
#  {'name': 'E11', 'color': -12566464},
#  {'name': 'E12', 'color': -12566464},
#  {'name': 'E13', 'color': -12566464},
#  {'name': 'E14', 'color': -12566464},
#  {'name': 'E15', 'color': -12566464},
#  {'name': 'E16', 'color': -12566464},
#  {'name': 'E17', 'color': -12566464},
#  {'name': 'E18', 'color': -12566464},
#  {'name': 'E19', 'color': -12566464},
#  {'name': 'E20', 'color': -12566464},
#  {'name': 'E21', 'color': -12566464},
#  {'name': 'F2', 'color': -12566464},
#  {'name': 'F3', 'color': -12566464},
#  {'name': 'F4', 'color': -12566464},
#  {'name': 'F5', 'color': -12566464},
#  {'name': 'F6', 'color': -12566464},
#  {'name': 'F7', 'color': -12566464},
#  {'name': 'F8', 'color': -12566464},
#  {'name': 'F9', 'color': -12566464},
#  {'name': 'F10', 'color': -12566464},
#  {'name': 'F11', 'color': -12566464},
#  {'name': 'F12', 'color': -12566464},
#  {'name': 'F13', 'color': -12566464},
#  {'name': 'F14', 'color': -12566464},
#  {'name': 'F15', 'color': -12566464},
#  {'name': 'F16', 'color': -12566464},
#  {'name': 'F17', 'color': -12566464},
#  {'name': 'F18', 'color': -12566464},
#  {'name': 'F19', 'color': -12566464},
#  {'name': 'F20', 'color': -12566464},
#  {'name': 'F21', 'color': -12566464},
#  {'name': 'G2', 'color': -12566464},
#  {'name': 'G3', 'color': -12566464},
#  {'name': 'G4', 'color': -12566464},
#  {'name': 'G5', 'color': -12566464},
#  {'name': 'G6', 'color': -12566464},
#  {'name': 'G7', 'color': -12566464},
#  {'name': 'G8', 'color': -12566464},
#  {'name': 'G9', 'color': -12566464},
#  {'name': 'G10', 'color': -12566464},
#  {'name': 'G11', 'color': -12566464},
#  {'name': 'G12', 'color': -12566464},
#  {'name': 'G13', 'color': -12566464},
#  {'name': 'G14', 'color': -12566464},
#  {'name': 'G15', 'color': -12566464},
#  {'name': 'G16', 'color': -12566464},
#  {'name': 'G17', 'color': -12566464},
#  {'name': 'G18', 'color': -12566464},
#  {'name': 'G19', 'color': -12566464},
#  {'name': 'G20', 'color': -12566464},
#  {'name': 'G21', 'color': -12566464},
#  {'name': 'H2', 'color': -12566464},
#  {'name': 'H3', 'color': -12566464},
#  {'name': 'H4', 'color': -12566464},
#  {'name': 'H5', 'color': -12566464},
#  {'name': 'H6', 'color': -12566464},
#  {'name': 'H7', 'color': -12566464},
#  {'name': 'H8', 'color': -12566464},
#  {'name': 'H9', 'color': -12566464},
#  {'name': 'H10', 'color': -12566464},
#  {'name': 'H11', 'color': -12566464},
#  {'name': 'H12', 'color': -12566464},
#  {'name': 'H13', 'color': -12566464},
#  {'name': 'H14', 'color': -12566464},
#  {'name': 'H15', 'color': -12566464},
#  {'name': 'H16', 'color': -12566464},
#  {'name': 'H17', 'color': -12566464},
#  {'name': 'H18', 'color': -12566464},
#  {'name': 'H19', 'color': -12566464},
#  {'name': 'H20', 'color': -12566464},
#  {'name': 'H21', 'color': -12566464},
#  {'name': 'I2', 'color': -12566464},
#  {'name': 'I3', 'color': -12566464},
#  {'name': 'I4', 'color': -12566464},
#  {'name': 'I5', 'color': -12566464},
#  {'name': 'I6', 'color': -12566464},
#  {'name': 'I7', 'color': -12566464},
#  {'name': 'I8', 'color': -12566464},
#  {'name': 'I9', 'color': -12566464},
#  {'name': 'I10', 'color': -12566464},
#  {'name': 'I11', 'color': -12566464},
#  {'name': 'I12', 'color': -12566464},
#  {'name': 'I13', 'color': -12566464},
#  {'name': 'I14', 'color': -12566464},
#  {'name': 'I15', 'color': -12566464},
#  {'name': 'I16', 'color': -12566464},
#  {'name': 'I17', 'color': -12566464},
#  {'name': 'I18', 'color': -12566464},
#  {'name': 'I19', 'color': -12566464},
#  {'name': 'I20', 'color': -12566464},
#  {'name': 'I21', 'color': -12566464},
#  {'name': 'J2', 'color': -12566464},
#  {'name': 'J3', 'color': -12566464},
#  {'name': 'J4', 'color': -12566464},
#  {'name': 'J5', 'color': -12566464},
#  {'name': 'J6', 'color': -12566464},
#  {'name': 'J7', 'color': -12566464},
#  {'name': 'J8', 'color': -12566464},
#  {'name': 'J9', 'color': -12566464},
#  {'name': 'J10', 'color': -12566464},
#  {'name': 'J11', 'color': -12566464},
#  {'name': 'J12', 'color': -12566464},
#  {'name': 'J13', 'color': -12566464},
#  {'name': 'J14', 'color': -12566464},
#  {'name': 'J15', 'color': -12566464},
#  {'name': 'J16', 'color': -12566464},
#  {'name': 'J17', 'color': -12566464},
#  {'name': 'J18', 'color': -12566464},
#  {'name': 'J19', 'color': -12566464},
#  {'name': 'J20', 'color': -12566464},
#  {'name': 'J21', 'color': -12566464},
#  {'name': 'K2', 'color': -12566464},
#  {'name': 'K3', 'color': -12566464},
#  {'name': 'K4', 'color': -12566464},
#  {'name': 'K5', 'color': -12566464},
#  {'name': 'K6', 'color': -12566464},
#  {'name': 'K7', 'color': -12566464},
#  {'name': 'K8', 'color': -12566464},
#  {'name': 'K9', 'color': -12566464},
#  {'name': 'K10', 'color': -12566464},
#  {'name': 'K11', 'color': -12566464},
#  {'name': 'K12', 'color': -12566464},
#  {'name': 'K13', 'color': -12566464},
#  {'name': 'K14', 'color': -12566464},
#  {'name': 'K15', 'color': -12566464},
#  {'name': 'K16', 'color': -12566464},
#  {'name': 'K17', 'color': -12566464},
#  {'name': 'K18', 'color': -12566464},
#  {'name': 'K19', 'color': -12566464},
#  {'name': 'K20', 'color': -12566464},
#  {'name': 'K21', 'color': -12566464},
#  {'name': 'L2', 'color': -12566464},
#  {'name': 'L3', 'color': -12566464},
#  {'name': 'L4', 'color': -12566464},
#  {'name': 'L5', 'color': -12566464},
#  {'name': 'L6', 'color': -12566464},
#  {'name': 'L7', 'color': -12566464},
#  {'name': 'L8', 'color': -12566464},
#  {'name': 'L9', 'color': -12566464},
#  {'name': 'L10', 'color': -12566464},
#  {'name': 'L11', 'color': -12566464},
#  {'name': 'L12', 'color': -12566464},
#  {'name': 'L13', 'color': -12566464},
#  {'name': 'L14', 'color': -12566464},
#  {'name': 'L15', 'color': -12566464},
#  {'name': 'L16', 'color': -12566464},
#  {'name': 'L17', 'color': -12566464},
#  {'name': 'L18', 'color': -12566464},
#  {'name': 'L19', 'color': -12566464},
#  {'name': 'L20', 'color': -12566464},
#  {'name': 'L21', 'color': -12566464},
#  {'name': 'M2', 'color': -12566464},
#  {'name': 'M3', 'color': -12566464},
#  {'name': 'M4', 'color': -12566464},
#  {'name': 'M5', 'color': -12566464},
#  {'name': 'M6', 'color': -12566464},
#  {'name': 'M7', 'color': -12566464},
#  {'name': 'M8', 'color': -12566464},
#  {'name': 'M9', 'color': -12566464},
#  {'name': 'M10', 'color': -12566464},
#  {'name': 'M11', 'color': -12566464},
#  {'name': 'M12', 'color': -12566464},
#  {'name': 'M13', 'color': -12566464},
#  {'name': 'M14', 'color': -12566464},
#  {'name': 'M15', 'color': -12566464},
#  {'name': 'M16', 'color': -12566464},
#  {'name': 'M17', 'color': -12566464},
#  {'name': 'M18', 'color': -12566464},
#  {'name': 'M19', 'color': -12566464},
#  {'name': 'M20', 'color': -12566464},
#  {'name': 'M21', 'color': -12566464},
#  {'name': 'N2', 'color': -12566464},
#  {'name': 'N3', 'color': -12566464},
#  {'name': 'N4', 'color': -12566464},
#  {'name': 'N5', 'color': -12566464},
#  {'name': 'N6', 'color': -12566464},
#  {'name': 'N7', 'color': -12566464},
#  {'name': 'N8', 'color': -12566464},
#  {'name': 'N9', 'color': -12566464},
#  {'name': 'N10', 'color': -12566464},
#  {'name': 'N11', 'color': -12566464},
#  {'name': 'N12', 'color': -12566464},
#  {'name': 'N13', 'color': -12566464},
#  {'name': 'N14', 'color': -12566464},
#  {'name': 'N15', 'color': -12566464},
#  {'name': 'N16', 'color': -12566464},
#  {'name': 'N17', 'color': -12566464},
#  {'name': 'N18', 'color': -12566464},
#  {'name': 'N19', 'color': -12566464},
#  {'name': 'N20', 'color': -12566464},
#  {'name': 'N21', 'color': -12566464}]
